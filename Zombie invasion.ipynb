# %%
import numpy as np
#Imports mathematical calculations
import matplotlib.pyplot as plt
#Allows for graphing

# %%
a=0.0095    #% transmission rate of zombie infection
b=0.005     #% kill rate
y=0.0001    #% resurrection rate
o=0.0001    #% capture rate
e=0.00001   #% Escape/kill rate 
t=0         #Intial hours
dz=1        #Initial zombies
ds=1000     #Initial population
o=0         #Inital quarantined zombies
dq=0        #Quarintined zombies rate
dr=0        #Initial zombie deaths
Y=[]     
Y_Z=[]
Y_ZD=[]
Y.append(ds)
Y_Z.append(dz)
Y_ZD.append
Res=0       #Inital zombie ressurection
print(t,"Hour","|Current population is ", ds,"|Current Zombies", dz,"|Zombie deaths",dr,'\n|Zombie Ressurection',Res,"\n" )
while ds>=1:
    
 #   while dz>=1:
    ZF= a*ds*dz*1/24     #Zombie infection rate
    ZD= b*ds*dz*1/24     #Zombie Destruction rate
    ZQ=o*dq*1/24         #Quarintine Zombie rate
    ds=-ZF+ds            #Total Human Population
    Res=y*dr             #Resurrection rate of dead zombies
    dz=dz+ZF-ZD+Res      #Total Zombie Population
    dr=dr+ZD-Res         #Total Resurrection of Dead zombies
    Y.append(ds) 
    Y_Z.append(dz)
    Y_ZD.append(dr)
    t=t+1
    print(t,"Hour","|Current population is ", ds,"|Current Zombies", dz,"|Zombie deaths",dr)
    print('Zombie Ressurected today',Res,'|Total beings',ds+dz+dr,"\n")
#print(Y)
#print(Y_Z)
# Out:
# 0 Hour |Current population is  1000 |Current Zombies 1 |Zombie deaths 0
# |Zombie Ressurection 0
#
# 1 Hour |Current population is  999.6041666666666 |Current Zombies 1.1875 |Zombie deaths 0.20833333333333334
# Zombie Ressurected today 0.0 |Total beings 1001.0
#
# 2 Hour |Current population is  999.1343006456162 |Current Zombies 1.4100889485677082 |Zombie deaths 0.45561040581597223
# Zombie Ressurected today 2.0833333333333336e-05 |Total beings 1000.9999999999999
#
# 3 Hour |Current population is  998.5766236357406 |Current Zombies 1.6742973037599103 |Zombie deaths 0.7490790604994134
# Zombie Ressurected today 4.5561040581597225e-05 |Total beings 1000.9999999999999
#
# 4 Hour |Current population is  997.9148242852725 |Current Zombies 1.987856114519272 |Zombie deaths 1.097319600208154
# Zombie Ressurected today 7.490790604994135e-05 |Total beings 1000.9999999999999
#
# ...
